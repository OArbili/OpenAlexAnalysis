# %%
#!/usr/bin/env python
# run_updated_analysis_v3.py
# Improved script with larger network fonts for better readability

from run_analysis import run_modified_analysis

if __name__ == "__main__":
    print("Running updated analysis with the following improvements:")
    print("- Only showing relationships with at least 3 collaborations")
    print("- Much larger font size in network visualizations")
    print("- Wider edges in the field-level network")
    print("- Analyzing top 50 collaborations with growth potential")
    
    # Run the analysis with the updated parameters
    result = run_modified_analysis(
        top_k=50,             # Show top 50 collaborations
        min_collaborations=3  # Only include collaborations with at least 3 instances
    )
    
    if result is not None and not result.empty:
        print(f"\nAnalysis complete! Found {len(result)} collaborations with significant growth potential.")
        print("(Only showing collaborations with at least 3 existing connections)")
        
        print("\nOutput files generated:")
        print("- interdisciplinary_network.png: Network with larger fonts (size 12) showing key collaborations")
        print("- field_level_network.png: Network with even larger fonts (size 14) showing field-level connections")
        print("- interdisciplinary_report.md: Detailed report with growth predictions")
        print("- interdisciplinary_growth.csv: Raw data for further analysis")
        
        print("\nNote: If the node labels are still difficult to read or overlapping, try:")
        print("1. Adjusting the figure size in the 'modified_visualization.py' file")
        print("2. Running with a smaller number of collaborations (e.g., --top_k 30)")
    else:
        print("Analysis completed but no results were generated.")
        print("This might mean there are no relationships with at least 3 collaborations.")
        print("Try running with a lower min_collaborations value if needed.")
# Out:
# Running updated analysis with the following improvements:
# - Only showing relationships with at least 3 collaborations
# - Much larger font size in network visualizations
# - Wider edges in the field-level network
# - Analyzing top 50 collaborations with growth potential
# Running modified analysis with min_collaborations=3 and top_k=50
# Initializing SubfieldGNN...
# Loaded 271780 articles
# Found 252 unique subfields
# Created graphs for 24 months
# Found data for 24 months: ['2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11', '2024-12']
# Preparing temporal data...
# Created 13 temporal graph samples for training
# Number of training examples: 13
# Loading model from subfield_gnn_model.pt...
# Model loaded successfully
# ...
