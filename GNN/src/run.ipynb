# %%
# !python run_model.py --debug
# Out:
# Running in DEBUG mode
# Initializing SubfieldGNN...
# Loaded 271780 articles
# Found 252 unique subfields
# Created graphs for 24 months
# Found data for 24 months: ['2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11', '2024-12']
# DEBUG MODE: Using window_size=2, prediction_horizon=1, epochs=5
# Preparing temporal data...
# Created 22 temporal graph samples for training
# Number of training examples: 22
# Training model...
# DEBUG MODE: Using simplified model that skips actual training
# DEBUG MODEL saved to 'subfield_gnn_model_debug.pt'
# Training completed in 0.01 seconds
# Generating predictions and reports...
# Extracting interdisciplinary collaborations...
# Analyzing interdisciplinary collaborations...
# Error in interdisciplinary report generation: name 'torch' is not defined
# ...

# %%
# !python run_model.py
# Out:
# Running in FULL mode
# Initializing SubfieldGNN...
# Loaded 271780 articles
# Found 252 unique subfields
# Created graphs for 24 months
# Found data for 24 months: ['2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11', '2024-12']
# Preparing temporal data...
# Created 13 temporal graph samples for training
# Number of training examples: 13
# Training model...
# Loaded 271780 articles
# Found 252 unique subfields
# Created graphs for 24 months
# Created 13 temporal graph samples for training
# Training on 9 samples (first 18 months)
# Validating on 4 samples (months 19-24)
# /home/arbili/.conda/envs/gnn2025/lib/python3.13/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# ...

# %%
# !python run_analysis.py
# Out:
# Running modified analysis with min_collaborations=1 and top_k=50
# Initializing SubfieldGNN...
# Loaded 271780 articles
# Found 252 unique subfields
# Created graphs for 24 months
# Found data for 24 months: ['2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11', '2024-12']
# Preparing temporal data...
# Created 13 temporal graph samples for training
# Number of training examples: 13
# Loading model from subfield_gnn_model.pt...
# ...

# %%
# !python run_sliding_window.py --window-size 50000 --stride 20000 --epochs 5 --seed 42
# Out:
# ...
# Running Subfield Collaboration Analysis with Sliding Window Approach
# ...
# Data path: ../data/all_articles_2023_2024.jsonl
# Window size: 50000 articles
# Stride: 20000 articles
# Training epochs: 5
# Random seed: 42
# Debug mode: No
# ...
# Starting analysis...
# Running in FULL mode
# Initializing SubfieldGNN...
# Loaded 271780 articles
# Found 252 unique subfields
# Created graphs for 24 months
# Found data for 24 months: ['2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11', '2024-12']
# FULL MODE: Using window_size=27178 (~10.0% of data), stride=13589, epochs=100
# Training model with sliding windows of articles...
# Loaded 271780 articles
# Found 252 unique subfields
# Created graphs for 24 months
# Creating sliding window graphs with window_size=27178, stride=13589
# ...
