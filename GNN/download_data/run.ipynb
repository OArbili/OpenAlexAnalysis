# %%
# !python downloads.py
# Out:
# Fetching page 1...
# Saved 200 articles to articles_2024/iterations/articles_page_1.jsonl
# Fetching page 2...
# Saved 200 articles to articles_2024/iterations/articles_page_2.jsonl
# Fetching page 3...
# Saved 200 articles to articles_2024/iterations/articles_page_3.jsonl
# Fetching page 4...
# Saved 200 articles to articles_2024/iterations/articles_page_4.jsonl
# Fetching page 5...
# Saved 200 articles to articles_2024/iterations/articles_page_5.jsonl
# Fetching page 6...
# Saved 200 articles to articles_2024/iterations/articles_page_6.jsonl
# Fetching page 7...
# Saved 200 articles to articles_2024/iterations/articles_page_7.jsonl
# Fetching page 8...
# Saved 200 articles to articles_2024/iterations/articles_page_8.jsonl
# Fetching page 9...
# Saved 200 articles to articles_2024/iterations/articles_page_9.jsonl
# Fetching page 10...
# Saved 200 articles to articles_2024/iterations/articles_page_10.jsonl
# Fetching page 11...
# ...
